# %% [markdown]
# <a href="https://colab.research.google.com/github/tanjirultusher/DATA-MANIPULATION-WITH-PANDAS/blob/main/pandas_py.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
pip install git+https://github.com/forrestbao/pyeeg.git
# Out:
# ...
#   Cloning https://github.com/forrestbao/pyeeg.git to /tmp/pip-req-build-fqnr5d2v
#   Running command git clone --filter=blob:none --quiet https://github.com/forrestbao/pyeeg.git /tmp/pip-req-build-fqnr5d2v
#   Resolved https://github.com/forrestbao/pyeeg.git to commit a6c18bb093e4748f9d9c208535a6ae024a0802b8
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for pyeeg: filename=pyeeg-0.4.4-py2.py3-none-any.whl size=28112 sha256=4eee5cfc135b36324321771582ee0bf5b91c76982d5963e327d5330b7690cdd4
#   Stored in directory: /tmp/pip-ephem-wheel-cache-vjj4jr8t/wheels/a8/c4/1a/cee09dcc12a11620066d35ace42e3c1e3bfbcc1db3a0ce7788
# Successfully built pyeeg
# ...

# %%
a = [1, 7, 2]
myvar = pd.Series(a, index = ["x", "y", "z"])
print(myvar)
calories = {"day1": 420, "day2": 380, "day3": 390}
myvar = pd.Series(calories)
print(myvar)
# Out:
# x    1
# y    7
# z    2
# dtype: int64
# day1    420
# day2    380
# day3    390
# dtype: int64

# %%
import pandas as pd
path = "/content/drive/MyDrive/datasets/nba.csv"
df = pd.read_csv(path)
# number of rows to return
n = 9
# creating series
series = df["Name"]
# returning top n rows
top = series.head(n = n)
# display
top
# Out:
# 0    Avery Bradley
# 1      Jae Crowder
# 2     John Holland
# 3      R.J. Hunter
# 4    Jonas Jerebko
# 5     Amir Johnson
# 6    Jordan Mickey
# 7     Kelly Olynyk
# 8     Terry Rozier
# Name: Name, dtype: object

# %%
# number of rows to return
n = 12
# creating series
series = df["Salary"]
# returning top n rows
bottom = series.tail(n = n)
# display
bottom
# Out:
# 446    12000000.0
# 447     1175880.0
# 448    15409570.0
# 449     1348440.0
# 450     2050000.0
# 451      981348.0
# 452     2239800.0
# 453     2433333.0
# 454      900000.0
# 455     2900000.0
# 456      947276.0
# 457           NaN
# Name: Salary, dtype: float64

# %%
# dataframe
import pandas as pd
data = {
 "calories": [420, 380, 390],
 "duration": [50, 40, 45]
}
#df = pd.DataFrame(data)
df = pd.DataFrame(data, index = ["day1", "day2", "day3"])
df
#df.loc[[0, 1]]
# Out:
#       calories  duration
# day1       420        50
# day2       380        40
# day3       390        45

# %% [markdown]
# **PANDAS CONCATENITION**

# %%
import pandas as pd

india_weather = pd.DataFrame({
    "city": ["mumbai","delhi","banglore"],
    "temperature": [32,45,30],
    "humidity": [80, 60, 78]
})
india_weather
# Out:
#        city  temperature  humidity
# 0    mumbai           32        80
# 1     delhi           45        60
# 2  banglore           30        78

# %%
us_weather = pd.DataFrame({
    "city": ["new york","chicago","orlando"],
    "temperature": [21,14,35],
    "humidity": [68, 65, 75]
})
us_weather
# Out:
#        city  temperature  humidity
# 0  new york           21        68
# 1   chicago           14        65
# 2   orlando           35        75

# %%
df = pd.concat([india_weather, us_weather])
df
# Out:
#        city  temperature  humidity
# 0    mumbai           32        80
# 1     delhi           45        60
# 2  banglore           30        78
# 0  new york           21        68
# 1   chicago           14        65
# 2   orlando           35        75

# %%
df = pd.concat([india_weather, us_weather], ignore_index=True)
df
# Out:
#        city  temperature  humidity
# 0    mumbai           32        80
# 1     delhi           45        60
# 2  banglore           30        78
# 3  new york           21        68
# 4   chicago           14        65
# 5   orlando           35        75

# %%
df = pd.concat([india_weather, us_weather], keys=["india", "us"])
df
# Out:
#              city  temperature  humidity
# india 0    mumbai           32        80
#       1     delhi           45        60
#       2  banglore           30        78
# us    0  new york           21        68
#       1   chicago           14        65
#       2   orlando           35        75

# %%
import pandas as pd
temperature_df = pd.DataFrame({
    "city": ["mumbai","delhi","banglore"],
    "temperature": [32,45,30],
}, index=[0,1,2])
temperature_df
# Out:
#        city  temperature
# 0    mumbai           32
# 1     delhi           45
# 2  banglore           30

# %%
windspeed_df = pd.DataFrame({
    "city": ["delhi","mumbai"],
    "windspeed": [7,12],
}, index=[1,0])
windspeed_df
# Out:
#      city  windspeed
# 1   delhi          7
# 0  mumbai         12

# %%
df = pd.concat([temperature_df,windspeed_df],axis=1)
df
# Out:
#        city  temperature    city  windspeed
# 0    mumbai           32  mumbai       12.0
# 1     delhi           45   delhi        7.0
# 2  banglore           30     NaN        NaN

# %% [markdown]
# **PANDAS MERGE DATAFRAME**

# %%
#merge dataframe
df1 = {
    "city": ["Dhaka", "Feni"],
    "temperature": [36, 34]
}
df2 = {
    "city": ["Dhaka", "Feni"],
    "humidity": [48, 45]
}
df1 = pd.DataFrame(df1)
df2 = pd.DataFrame(df2)

df3 = pd.merge(df1,df2, on ="city")  # how="outer/inner/left/right" , indicator ="true"
df3
# Out:
#     city  temperature  humidity
# 0  Dhaka           36        48
# 1   Feni           34        45

# %%
import pandas as pd
df1 ={
     "city": ["Dhaka", "Feni","Barisal"],
     "temperature": [36, 34, 39]
}
df2 ={
    #"city": ["Dhaka", "Feni", "barisal"],
    "city": ["Dhaka", "Feni", "Barisal"],
    "humidity": [48, 45, 44]
}
df1 = pd.DataFrame(df1)
print(df1)
df2 = pd.DataFrame(df2)
print(df2)
df3 = pd.merge(df1,df2, on ="city")
print(df3)
# Out:
#       city  temperature
# 0    Dhaka           36
# 1     Feni           34
# 2  Barisal           39
#       city  humidity
# 0    Dhaka        48
# 1     Feni        45
# 2  Barisal        44
#       city  temperature  humidity
# 0    Dhaka           36        48
# 1     Feni           34        45
# 2  Barisal           39        44

# %% [markdown]
# **PANDAS PIVOT TBALE**

# %%
#pivot table
path = "/content/drive/MyDrive/datasets/Book2.csv"
df = pd.read_csv(path)
df.pivot(index="city",columns="date",values="humidity")
# Out:
# date    1/1/2017  1/2/2027  1/3/2017
# city
# dhaka         55        53        45
# feni          44        55        66
# khulna        66        43        76

# %%
import pandas as pd
path = "/content/drive/MyDrive/datasets/Book2.csv"
df = pd.read_csv(path)
df.pivot(index='city',columns='date')
# Out:
#        temperature                   humidity
# date      1/1/2017 1/2/2027 1/3/2017 1/1/2017 1/2/2027 1/3/2017
# city
# dhaka           65       61       70       55       53       45
# feni            38       40       41       44       55       66
# khulna          72       75       39       66       43       76

# %%
df.isnull().sum()
# Out:
# date           0
# city           0
# temperature    0
# humidity       0
# dtype: int64

# %%
df.pivot(index='date',columns='city')
# Out:
#          temperature             humidity
# city           dhaka feni khulna    dhaka feni khulna
# date
# 1/1/2017          65   38     72       55   44     66
# 1/2/2027          61   40     75       53   55     43
# 1/3/2017          70   41     39       45   66     76

# %%
df.pivot_table(index="city",columns="date", aggfunc="sum", margins=True)
#aggfunc=mean,sum   margins=true means to get all row and functins total
# Out:
#        humidity                        temperature
# date   1/1/2017 1/2/2027 1/3/2017  All    1/1/2017 1/2/2027 1/3/2017  All
# city
# dhaka        55       53       45  153          65       61       70  196
# feni         44       55       66  165          38       40       41  119
# khulna       66       43       76  185          72       75       39  186
# All         165      151      187  503         175      176      150  501

# %%
path = "/content/drive/MyDrive/datasets/data.csv"
df = pd.read_csv(path)
df.to_string() # to_string method print the whole dataset
# Out:
# '     Duration  Pulse  Maxpulse  Calories\n0          60    110       130     409.1\n1          60    117       145     479.0\n2          60    103       135     340.0\n3          45    109       175     282.4\n4          45    117       148     406.0\n5          60    102       127     300.0\n6          60    110       136     374.0\n7          45    104       134     253.3\n8          30    109       133     195.1\n9          60     98       124     269.0\n10         60    103       147     329.3\n11         60    100       120     250.7\n12         60    106       128     345.3\n13         60    104       132     379.3\n14         60     98       123     275.0\n15         60     98       120     215.2\n16         60    100       120     300.0\n17         45     90       112       NaN\n18         60    103       123     323.0\n19         45     97       125     243.0\n20         60    108       131     364.2\n21         45    100       119     282.0\n22         60    130       101 
# ...

# %% [markdown]
# **HANDLEING MISSING DATA - DROPNA METHOD**

# %%
df.info() #e info() method also tells us how many Non-Null values there are present
#df.dropna() #remove null values from the datasets
df.loc[[17,27], "Calories"]= 130 #replace null values
df.head(30) # return the top 30 rows
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 169 entries, 0 to 168
# Data columns (total 4 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Duration  169 non-null    int64
#  1   Pulse     169 non-null    int64
#  2   Maxpulse  169 non-null    int64
#  3   Calories  164 non-null    float64
# dtypes: float64(1), int64(3)
# memory usage: 5.4 KB
#     Duration  Pulse  Maxpulse  Calories
# 0         60    110       130     409.1
# 1         60    117       145     479.0
# 2         60    103       135     340.0
# 3         45    109       175     282.4
# 4         45    117       148     406.0
# 5         60    102       127     300.0
# 6         60    110       136     374.0
# 7         45    104       134     253.3
# 8         30    109       133     195.1
# 9         60     98       124     269.0
# 10        60    103       147     329.3
# 11        60    100       120     250.7
# 12        60    106       128     345.3
# ...

# %% [markdown]
# **REMOVE DUPLICATE VALUES IN PANDAS**

# %%
#drop duplicates values from dataframe
path = "/content/drive/MyDrive/datasets/Book4.csv"
df = pd.read_csv(path)
df.drop_duplicates(inplace = True)
df
#df.drop('date', axis=1)
#df = df.drop(column=['column_name'])
#df.drop('row_name', axis=0)
# Out:
#                  date      city  temperature  humidity
# 0             5/1/2017  newyork           64        55
# 1             5/2/2017  newyork           76        44
# 2             5/3/2017  newyork           62        56
# 3             5/1/2017   mumbai           55        57
# 4             5/2/2017   mumbai           44        53
# 5             5/3/2017   mumbai           77        65
# 6  Monday, May 1, 2017  beijing           56        62
# 7             5/2/2017  beijing           59        69
# 8             5/3/2017  beijing           61        75

# %% [markdown]
# **PANDAS MELT METHOD - RESHAPE DATASET**

# %%
#reshape dataframe
path = "/content/drive/MyDrive/datasets/Book5.csv"
df=pd.read_csv(path)
df1 = pd.melt(df, id_vars=["day"],var_name="city",value_name="temperature")
df1
# Out:
#           day     city  temperature
# 0      Monday  chicago           43
# 1     Tuesday  chicago           45
# 2   Wednesday  chicago           55
# 3    Thursday  chicago           53
# 4      Friday  chicago           49
# 5    Saturday  chicago           60
# 6      Sunday  chicago           65
# 7      Monday    dhaka           34
# 8     Tuesday    dhaka           33
# 9   Wednesday    dhaka           34
# 10   Thursday    dhaka           35
# 11     Friday    dhaka           38
# 12   Saturday    dhaka           39
# 13     Sunday    dhaka           32
# 14     Monday     feni           38
# 15    Tuesday     feni           38
# 16  Wednesday     feni           34
# 17   Thursday     feni           35
# 18     Friday     feni           36
# 19   Saturday     feni           34
# 20     Sunday     feni           32

# %% [markdown]
# **PANDAS CROSSTAB METHOD**

# %%
#crosstab
import pandas as pd
path = "/content/drive/MyDrive/datasets/Book6.xlsx"
df = pd.read_excel(path)
df
# Out:
#       name  nationality     sex  age handedness
# 0     kathy         usa  female   23      right
# 1     linda         usa  female   18      right
# 2     peter         usa    male   19       left
# 3      jhon         usa    male   22       left
# 4   fatima   bangladesh  female   31       left
# 5     kabir  bangladesh    male   25       left
# 6    dhaval       india    male   35       left
# 7    shudir       india    male   31      right
# 8    parvir       india    male   37      right
# 9      yan        china  female   52       left
# 10     juan       china  female   58       left
# 11    liang       china    male   43       left

# %%
pd.crosstab(df.nationality,df.handedness)
# Out:
# handedness   left  right
# nationality
# bangladesh      2      0
# china           3      0
# india           1      2
# usa             2      2

# %%
pd.crosstab(df.sex,df.handedness,margins=True)
# Out:
# handedness  left  right  All
# sex
# female         3      2    5
# male           5      2    7
# All            8      4   12

# %%
pd.crosstab(df.sex,[df.handedness,df.nationality],margins=True)
# Out:
# handedness        left                 right     All
# nationality bangladesh china india usa india usa
# sex
# female               1     2     0   0     0   2   5
# male                 1     1     1   2     2   0   7
# All                  2     3     1   2     2   2  12

# %%
pd.crosstab([df.nationality,df.sex],[df.handedness],margins=True)
# Out:
# handedness          left  right  All
# nationality sex
# bangladesh  female     1      0    1
#             male       1      0    1
# china       female     2      0    2
#             male       1      0    1
# india       male       1      2    3
# usa         female     0      2    2
#             male       2      0    2
# All                    8      4   12

# %%
pd.crosstab([df.sex],[df.handedness],normalize= 'index')
# Out:
# handedness      left     right
# sex
# female      0.600000  0.400000
# male        0.714286  0.285714

# %%
import numpy as np
pd.crosstab([df.sex],[df.handedness],values=df.age, aggfunc=np.average)
# Out:
# handedness  left  right
# sex
# female      47.0   20.5
# male        28.8   34.0

# %% [markdown]
# ***PANDAS GROUPBY METHOD ***

# %%
#groupby in pandas
import pandas as pd
path = "/content/drive/MyDrive/datasets/Book6.xlsx"
df = pd.read_excel(path)
g = df.groupby('nationality')
g

# %%
for nationality, nationality_df in g:
  print(nationality)
  print(nationality_df)
# Out:
# bangladesh
#      name  nationality     sex  age handedness
# 4  fatima   bangladesh  female   31       left
# 5    kabir  bangladesh    male   25       left
# china
#     name  nationality     sex  age handedness
# 9    yan        china  female   52       left
# 10   juan       china  female   58       left
# 11  liang       china    male   43       left
# india
#     name  nationality   sex  age handedness
# 6  dhaval       india  male   35       left
# 7  shudir       india  male   31      right
# 8  parvir       india  male   37      right
# usa
#    name  nationality     sex  age handedness
# 0  kathy         usa  female   23      right
# 1  linda         usa  female   18      right
# 2  peter         usa    male   19       left
# 3   jhon         usa    male   22       left

# %%
g.get_group('bangladesh')
# Out:
#      name  nationality     sex  age handedness
# 4  fatima   bangladesh  female   31       left
# 5    kabir  bangladesh    male   25       left

# %%
g.describe()   #g.max()/min()/mean()/size()/count()
# Out:
#               age
#             count       mean       std   min    25%   50%    75%   max
# nationality
# bangladesh    2.0  28.000000  4.242641  25.0  26.50  28.0  29.50  31.0
# china         3.0  51.000000  7.549834  43.0  47.50  52.0  55.00  58.0
# india         3.0  34.333333  3.055050  31.0  33.00  35.0  36.00  37.0
# usa           4.0  20.500000  2.380476  18.0  18.75  20.5  22.25  23.0

# %% [markdown]
# **Handling Missing Data in Pandas**

# %%
#handling missing data in pandas
import pandas as pd
path = "/content/drive/MyDrive/datasets/Book7.csv"
df = pd.read_csv(path)
df
# Out:
#     Duration  Pulse  Maxpulse  Calories
# 0       60.0  110.0     130.0     409.1
# 1       60.0  117.0     145.0     479.0
# 2       60.0  103.0     135.0     340.0
# 3       45.0  109.0     175.0     282.4
# 4        NaN  117.0     148.0     406.0
# 5       60.0  102.0       NaN     300.0
# 6       60.0    NaN     136.0     374.0
# 7       45.0  104.0     134.0     253.3
# 8       30.0  109.0       NaN       NaN
# 9       60.0   98.0     124.0     269.0
# 10       NaN  103.0     147.0     329.3
# 11      60.0    NaN     120.0     250.7
# 12      60.0  106.0     128.0     345.3
# 13      60.0  104.0       NaN     379.3
# 14      60.0   98.0     123.0     275.0
# 15       NaN   98.0     120.0       NaN
# 16      60.0  100.0     120.0     300.0
# 17      45.0   90.0     112.0       NaN
# 18      60.0  103.0     123.0     323.0
# 19      45.0   97.0     125.0     243.0

# %%
new_df = df.fillna({
    'Duration':0,
    'Pulse':0,
    'Maxpulse':0,
    'Calories':0
})
new_df
# Out:
#           Duration  Pulse  Maxpulse  Calories
# 0             60.0  110.0     130.0     409.1
# 1             60.0  117.0     145.0     479.0
# 2             60.0  103.0     135.0     340.0
# 3             45.0  109.0     175.0     282.4
# 4              0.0  117.0     148.0     406.0
# 5             60.0  102.0       0.0     300.0
# 6             60.0    0.0     136.0     374.0
# 7             45.0  104.0     134.0     253.3
# 8             30.0  109.0       0.0       0.0
# 9             60.0   98.0     124.0     269.0
# 10             0.0  103.0     147.0     329.3
# 11            60.0    0.0     120.0     250.7
# 12            60.0  106.0     128.0     345.3
# 13            60.0  104.0       0.0     379.3
# 14            60.0   98.0     123.0     275.0
# 15             0.0   98.0     120.0       0.0
# 16            60.0  100.0     120.0     300.0
# 17            45.0   90.0     112.0       0.0
# 18            60.0  103.0     123.0     323.0
# ...

# %%
new_df = df.fillna(method='ffill') #method='bfill'
new_df
# Out:
#           Duration  Pulse  Maxpulse  Calories
# 0             60.0  110.0     130.0     409.1
# 1             60.0  117.0     145.0     479.0
# 2             60.0  103.0     135.0     340.0
# 3             45.0  109.0     175.0     282.4
# 4             45.0  117.0     148.0     406.0
# 5             60.0  102.0     148.0     300.0
# 6             60.0  102.0     136.0     374.0
# 7             45.0  104.0     134.0     253.3
# 8             30.0  109.0     134.0     253.3
# 9             60.0   98.0     124.0     269.0
# 10            60.0  103.0     147.0     329.3
# 11            60.0  103.0     120.0     250.7
# 12            60.0  106.0     128.0     345.3
# 13            60.0  104.0     128.0     379.3
# 14            60.0   98.0     123.0     275.0
# 15            60.0   98.0     120.0     275.0
# 16            60.0  100.0     120.0     300.0
# 17            45.0   90.0     112.0     300.0
# 18            60.0  103.0     123.0     323.0
# ...

# %%
import pandas as pd
path = "/content/drive/MyDrive/datasets/Book7.csv"
df = pd.read_csv(path)
df['Calories'].describe() # max(),min(),mean(), std(standard_deviation)
# Out:
# count     17.000000
# mean     326.964706
# std       65.849924
# min      243.000000
# 25%      275.000000
# 50%      323.000000
# 75%      374.000000
# max      479.000000
# Name: Calories, dtype: float64

# %%
import pandas as pd
path = "/content/drive/MyDrive/datasets/weather_data.csv"
df = pd.read_csv(path)
new_df = df.fillna(0)
new_df
# Out:
#          day  temperature  windspeed   event
# 0   1/1/2017         32.0        6.0    Rain
# 1   1/4/2017          0.0        9.0   Sunny
# 2   1/5/2017         28.0        0.0    Snow
# 3   1/6/2017          0.0        7.0       0
# 4   1/7/2017         32.0        0.0    Rain
# 5   1/8/2017          0.0        0.0   Sunny
# 6   1/9/2017          0.0        0.0       0
# 7  1/10/2017         34.0        8.0  Cloudy
# 8  1/11/2017         40.0       12.0   Sunny

# %%
dt = pd.date_range("01-01-2017","01-11-2017")
idx = pd.DatetimeIndex(dt)
df = df.reindex(idx)
df
# Out:
#             day  temperature  windspeed event
# 2017-01-01  NaN          NaN        NaN   NaN
# 2017-01-02  NaN          NaN        NaN   NaN
# 2017-01-03  NaN          NaN        NaN   NaN
# 2017-01-04  NaN          NaN        NaN   NaN
# 2017-01-05  NaN          NaN        NaN   NaN
# 2017-01-06  NaN          NaN        NaN   NaN
# 2017-01-07  NaN          NaN        NaN   NaN
# 2017-01-08  NaN          NaN        NaN   NaN
# 2017-01-09  NaN          NaN        NaN   NaN
# 2017-01-10  NaN          NaN        NaN   NaN
# 2017-01-11  NaN          NaN        NaN   NaN

# %% [markdown]
# **Pandas practice**

# %%
import pandas as pd
path = "/content/drive/MyDrive/datasets/Ecommerce Purchases.unknown"
df = pd.read_csv(path)
df
# Out:
#                                                 Address    Lot AM or PM  \
# 0     16629 Pace Camp Apt. 448\nAlexisborough, NE 77...  46 in       PM
# 1     9374 Jasmine Spurs Suite 508\nSouth John, TN 8...  28 rn       PM
# 2                      Unit 0065 Box 5052\nDPO AP 27450  94 vE       PM
# 3                 7780 Julia Fords\nNew Stacy, WA 45798  36 vm       PM
# 4     23012 Munoz Drive Suite 337\nNew Cynthia, TX 5...  20 IE       AM
# ...                                                 ...    ...      ...
# 9995      966 Castaneda Locks\nWest Juliafurt, CO 96415  92 XI       PM
# 9996  832 Curtis Dam Suite 785\nNorth Edwardburgh, T...  41 JY       AM
# 9997              Unit 4434 Box 6343\nDPO AE 28026-0283  74 Zh       AM
# 9998               0096 English Rest\nRoystad, IA 12457  74 cL       PM
# 9999     40674 Barrett Stravenue\nGrimesville, WI 79682  64 Hr       AM
#
#                                            Browser Info  \
# ...

# %%
df.head(10)
# Out:
#                                              Address    Lot AM or PM  \
# 0  16629 Pace Camp Apt. 448\nAlexisborough, NE 77...  46 in       PM
# 1  9374 Jasmine Spurs Suite 508\nSouth John, TN 8...  28 rn       PM
# 2                   Unit 0065 Box 5052\nDPO AP 27450  94 vE       PM
# 3              7780 Julia Fords\nNew Stacy, WA 45798  36 vm       PM
# 4  23012 Munoz Drive Suite 337\nNew Cynthia, TX 5...  20 IE       AM
# 5  7502 Powell Mission Apt. 768\nTravisland, VA 3...  21 XT       PM
# 6     93971 Conway Causeway\nAndersonburgh, AZ 75107  96 Xt       AM
# 7  260 Rachel Plains Suite 366\nCastroberg, WV 24...  96 pG       PM
# 8            2129 Dylan Burg\nNew Michelle, ME 28650  45 JN       PM
# 9    3795 Dawson Extensions\nLake Tinafort, ID 88739  15 Ug       AM
#
#                                         Browser Info  \
# 0  Opera/9.56.(X11; Linux x86_64; sl-SI) Presto/2...
# 1  Opera/8.93.(Windows 98; Win 9x 4.90; en-US) Pr...
# ...

# %%
df.tail(10)
# Out:
#                                                 Address    Lot AM or PM  \
# 9990  75731 Molly Springs\nWest Danielle, VT 96934-5102  93 ty       PM
# 9991              PSC 8165, Box 8498\nAPO AP 60327-0346  50 dA       AM
# 9992  885 Allen Mountains Apt. 230\nWallhaven, LA 16995  40 vH       PM
# 9993  7555 Larson Locks Suite 229\nEllisburgh, MA 34...  72 jg       PM
# 9994       6276 Rojas Hollow\nLake Louis, WY 56410-7837  93 Ex       PM
# 9995      966 Castaneda Locks\nWest Juliafurt, CO 96415  92 XI       PM
# 9996  832 Curtis Dam Suite 785\nNorth Edwardburgh, T...  41 JY       AM
# 9997              Unit 4434 Box 6343\nDPO AE 28026-0283  74 Zh       AM
# 9998               0096 English Rest\nRoystad, IA 12457  74 cL       PM
# 9999     40674 Barrett Stravenue\nGrimesville, WI 79682  64 Hr       AM
#
#                                            Browser Info  \
# 9990  Mozilla/5.0 (Macintosh; Intel Mac OS X 10_7_4;...
# 9991  Mozilla/5.0 (compatible; MSIE 8.0; Windows NT ...
# ...

# %%
df.isnull()
# Out:
#       Address    Lot  AM or PM  Browser Info  Company  Credit Card  \
# 0       False  False     False         False    False        False
# 1       False  False     False         False    False        False
# 2       False  False     False         False    False        False
# 3       False  False     False         False    False        False
# 4       False  False     False         False    False        False
# ...       ...    ...       ...           ...      ...          ...
# 9995    False  False     False         False    False        False
# 9996    False  False     False         False    False        False
# 9997    False  False     False         False    False        False
# 9998    False  False     False         False    False        False
# 9999    False  False     False         False    False        False
#
#       CC Exp Date  CC Security Code  CC Provider  Email    Job  IP Address  \
# 0           False             False        False  False  False       False
# ...

# %%
df.shape
# Out:
# (10000, 14)

# %%
df.columns
# Out:
# Index(['Address', 'Lot', 'AM or PM', 'Browser Info', 'Company', 'Credit Card',
#        'CC Exp Date', 'CC Security Code', 'CC Provider', 'Email', 'Job',
#        'IP Address', 'Language', 'Purchase Price'],
#       dtype='object')

# %%
df.dtypes
# Out:
# Address              object
# Lot                  object
# AM or PM             object
# Browser Info         object
# Company              object
# Credit Card           int64
# CC Exp Date          object
# CC Security Code      int64
# CC Provider          object
# Email                object
# Job                  object
# IP Address           object
# Language             object
# Purchase Price      float64
# dtype: object

# %% [markdown]
# **Highest And Lowest Average Purchase Prices**

# %%
df1 = df['Purchase Price']
df1.mean()
# Out:
# 50.347302

# %%
df1.max()
# Out:
# 99.99

# %% [markdown]
# **Job Title Contains Engineer**

# %%
df[df['Job'] == 'Drilling engineer']
# Out:
#                                                 Address    Lot AM or PM  \
# 1     9374 Jasmine Spurs Suite 508\nSouth John, TN 8...  28 rn       PM
# 3                 7780 Julia Fords\nNew Stacy, WA 45798  36 vm       PM
# 779               PSC 9956, Box 2820\nAPO AE 81969-8768  14 yG       PM
# 1104  32038 Adams Valley Suite 436\nNorth Kaylachest...  44 eL       AM
# 1303  98753 Smith Radial Suite 963\nSouth Jasmine, R...  45 cj       AM
# 1531                   PSC 7147, Box 5613\nAPO AE 35453  76 Cs       AM
# 2989  98274 Henderson Expressway Suite 475\nPort Hay...  32 Ls       PM
# 3558  01333 Nicholas Hill Suite 739\nEast Maria, DE ...  45 tj       AM
# 3753  96370 Shannon Isle Apt. 581\nRandallton, PA 62...  05 cD       PM
# 4840  031 Lang Plaza\nLake Matthewchester, NE 79519-...  13 DM       PM
# 4969   5865 Wendy Square\nNew Jacqueline, SD 40769-9181  02 JU       PM
# 4981                   PSC 9130, Box 5382\nAPO AP 58279  36 MU       PM
# ...

# %% [markdown]
# **Job Title Contains Engineer**

# %%
df[df['Job'].str.contains('engineer')]
# Out:
#                                                 Address    Lot AM or PM  \
# 1     9374 Jasmine Spurs Suite 508\nSouth John, TN 8...  28 rn       PM
# 3                 7780 Julia Fords\nNew Stacy, WA 45798  36 vm       PM
# 50      41159 Michael Centers\nAdamsfort, RI 37108-6674  46 Ce       PM
# 103                480 Ronald Cape\nJohnville, MA 53644  11 wg       AM
# 193   1010 Mahoney Mills Suite 486\nWest Daniellevie...  70 Fd       AM
# ...                                                 ...    ...      ...
# 9934     52276 Smith Cliffs\nLake Vanessaview, AL 91791  40 nG       AM
# 9948  95544 Johnson Isle Suite 939\nMichaelberg, RI ...  91 bW       AM
# 9970              0060 Keith Stream\nWestport, CO 47097  11 nt       PM
# 9977  02182 Keith Expressway\nEast Shannon, CT 20578...  34 RL       AM
# 9996  832 Curtis Dam Suite 785\nNorth Edwardburgh, T...  41 JY       AM
#
#                                            Browser Info  \
# ...

# %%
# Case Insensitive Search
len(df[df['Job'].str.contains('engineer', case=False)])
# Out:
# 984

# %% [markdown]
# **Find Email Of the person with following IP address :132.207.160.22**

# %%
df[df['IP Address'] == '132.207.160.22'][['Email']]
# Out:
#                             Email
# 2  amymiller@morales-harrison.com

# %% [markdown]
# **How Many People Have Mastercard As Their Credit Card Provider And Made A Purchase Above 50?**

# %%
len(df[(df['CC Provider'] == 'Mastercard') & (df['Purchase Price'] >= 50)])
# Out:
# 405

# %% [markdown]
# **Find Email of The Person With The Following Credit Card Number: 4664825258997302**

# %%
df[df['Credit Card'] == 4664825258997302][['Email']]
# Out:
#                   Email
# 9992  bberry@wright.net

# %%
df.loc[3]
# Out:
# Address                         7780 Julia Fords\nNew Stacy, WA 45798
# Lot                                                             36 vm
# AM or PM                                                           PM
# Browser Info        Mozilla/5.0 (Macintosh; Intel Mac OS X 10_8_0 ...
# Company                               Williams, Marshall and Buchanan
# Credit Card                                          6011578504430710
# CC Exp Date                                                     02/24
# CC Security Code                                                  384
# CC Provider                                                  Discover
# Email                                     brent16@olson-robinson.info
# Job                                                 Drilling engineer
# IP Address                                               30.250.74.19
# Language                                                           es
# ...

# %% [markdown]
# **How Many People Have A Credit Card the EXpires in 2020**

# %%
import pandas as pd
path = "/content/drive/MyDrive/datasets/Ecommerce Purchases.unknown"
df = pd.read_csv(path)
def fun():
    count =0
    for i in df['CC Exp Date']:
        if i.split('/')[1]=='20':
            count = count+1
    print(count)
fun()
# Out:
# 988

# %% [markdown]
# **How many people have French 'fr' as their Language ?**

# %%
len(df[df['Language'] == 'fr'])

# %% [markdown]
# **How Many People Purchase During The AM and How Many People Purchase During PM ?**

# %%
print(df['AM or PM'].value_counts())

# %% [markdown]
# **Find Email of The of Person With The Following Credit Card Number 4664825258997302**

# %%
import pandas as pd
path = "/content/drive/MyDrive/datasets/Ecommerce Purchases.unknown"
df = pd.read_csv(path)
df[df['Credit Card' ]== 4664825258997302][['Email']]
# Out:
#                   Email
# 9992  bberry@wright.net

# %% [markdown]
# **Top 5 most Popular Email Providers(e.g. gmail.com, yahoo.com,etc..)**

# %%
list = []
for email in df['Email']:
    list.append(email.split('@')[1])
print(list)
# Out:
# ['yahoo.com', 'reed.com', 'morales-harrison.com', 'olson-robinson.info', 'gmail.com', 'gmail.com', 'yahoo.com', 'parks.info', 'rasmussen.com', 'hunt-huerta.com', 'hotmail.com', 'coleman.com', 'hotmail.com', 'yahoo.com', 'yahoo.com', 'yahoo.com', 'wilson.com', 'hall.com', 'yahoo.com', 'gmail.com', 'smith.info', 'hotmail.com', 'gmail.com', 'gardner-meadows.com', 'yahoo.com', 'mooney.com', 'gmail.com', 'hotmail.com', 'yahoo.com', 'yahoo.com', 'hotmail.com', 'hotmail.com', 'atkinson.com', 'yahoo.com', 'carey-davis.com', 'mcdowell.com', 'walsh.com', 'frederick.info', 'boyd-english.org', 'wells-carlson.info', 'dickerson.com', 'yahoo.com', 'gmail.com', 'martinez-thomas.com', 'yahoo.com', 'chambers.com', 'gmail.com', 'glenn.org', 'allen.com', 'gmail.com', 'obrien.org', 'cook-castillo.com', 'hotmail.com', 'yahoo.com', 'hotmail.com', 'yahoo.com', 'lawrence-warren.biz', 'morris.com', 'howe.com', 'walton.org', 'jones.biz', 'gmail.com', 'simmons-gutierrez.org', 'yahoo.com', 'gardner-anderson.com'
# ...
